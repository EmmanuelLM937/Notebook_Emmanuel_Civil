# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelLM937/Notebook_Emmanuel_Civil/blob/main/notebook_1_ipyns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CONTENIDOS
#
# 1. INTRODUCIÓN
# 2. OBJETIVOS
# 3. METODOLOGÍA
# 4. ANÁLISIS
# 5. ECUACIONES

# %% [markdown]
# INTRODUCCIÓN
#
# HDSAHGDHGDHQWGDHQWBVDBWQJVWQJHCFHWQBCXZGCBADWVBDJWQDQBCFHBFC

# %% [markdown]
# OBJETIVOS
